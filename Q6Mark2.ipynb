# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
from collections import OrderedDict

from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings

design = designs.DesignPlanar()
gui = MetalGUI(design)

# if you disable the next line, then you will need to delete a component [<component>.delete()] before recreating it
design.overwrite_enabled = True

# %%
from qiskit_metal.qlibrary.qubits.transmon_pocket_cl import TransmonPocketCL
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.terminations.launchpad_wb_coupled import LaunchpadWirebondCoupled

# %%
def connect(cpw_name: str, pin1_comp_name: str, pin1_comp_pin: str, pin2_comp_name: str, pin2_comp_pin: str,
            length: str, asymmetry='0 um'):
    """Connect two pins with a CPW."""
    myoptions = Dict(
        pin_inputs=Dict(
            start_pin=Dict(
                component=pin1_comp_name,
                pin=pin1_comp_pin),
            end_pin=Dict(
                component=pin2_comp_name,
                pin=pin2_comp_pin)),
        total_length=length)
    myoptions.update(cpw_options)
    myoptions.meander.asymmetry = asymmetry
    return RouteMeander(design, cpw_name, myoptions)

# %%
design.variables['cpw_width'] = '10 um'
design.variables['cpw_gap'] = '6 um'
design._chips['main']['size']['size_x'] = '10mm'
design._chips['main']['size']['size_y'] = '10mm'

# %%
transmon_options = dict(
    connection_pads=dict(
        a = dict(loc_W=+1, loc_H=-1, pad_width='70um', cpw_extend = '50um'),
        b = dict(loc_W=-1, loc_H=-1, pad_width='125um', cpw_extend = '50um'),
        c = dict(loc_W=-1, loc_H=+1, pad_width='110um', cpw_extend = '50um')
    ),
    gds_cell_name='FakeJunction_01',
    cl_off_center = '-50um',
    cl_pocket_edge = '180'
)

# %%
offset_tm = 0  #we the transmon slightly out of center-line

q1 = TransmonPocketCL(design, 'Q1', options = dict(
    pos_x='3000um', pos_y='0um', **transmon_options))
q2 = TransmonPocketCL(design, 'Q2', options = dict(
    pos_x='1500um', pos_y='2000um', orientation = '90', **transmon_options))
q3 = TransmonPocketCL(design, 'Q3', options = dict(
    pos_x='-1500um', pos_y='2000um', orientation = '90', **transmon_options))
q4 = TransmonPocketCL(design, 'Q4', options = dict(
    pos_x='-3000um', pos_y='0um', orientation = '180', **transmon_options))
q5 = TransmonPocketCL(design, 'Q5', options = dict(
    pos_x='-1500um', pos_y='-2000um', orientation = '270', **transmon_options))
q6 = TransmonPocketCL(design, 'Q6', options = dict(
    pos_x='1500um', pos_y='-2000um', orientation = '270', **transmon_options))

gui.rebuild()
gui.autoscale()
gui.screenshot()
# Out:
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
RouteMeander.get_template_options(design)
# Out:
# {'chip': 'main',
#  'layer': '1',
#  'pin_inputs': {'start_pin': {'component': '', 'pin': ''},
#   'end_pin': {'component': '', 'pin': ''}},
#  'fillet': '0',
#  'lead': {'start_straight': '0mm',
#   'end_straight': '0mm',
#   'start_jogged_extension': '',
#   'end_jogged_extension': ''},
#  'total_length': '7mm',
#  'trace_width': 'cpw_width',
#  'meander': {'spacing': '200um', 'asymmetry': '0um'},
#  'snap': 'true',
#  'prevent_short_edges': 'true',
#  'hfss_wire_bonds': False,
#  'q3d_wire_bonds': False}

# %%
fillet='99.99um'
cpw_options = Dict(
    lead=Dict(
        start_straight='100um',
        end_straight='250um'),
    fillet=fillet
    )

# %%
asym = 300
offset_tm = 50
cpw1 = connect('cpw1', 'Q1', 'c', 'Q2', 'b', '7000um', f'-{asym-1.25*offset_tm}um')
cpw2 = connect('cpw2', 'Q3', 'b', 'Q2', 'c', '7000um', f'+{asym-1.25*offset_tm}um')
cpw3 = connect('cpw3', 'Q4', 'b', 'Q3', 'c', '7000um', f'-{asym+0.75*offset_tm}um')
cpw4 = connect('cpw4', 'Q4', 'c', 'Q5', 'b', '7000um', f'+{asym+0.75*offset_tm}um')
cpw5 = connect('cpw5', 'Q5', 'c', 'Q6', 'b', '7000um', f'-{asym+0.4*offset_tm}um')
cpw6 = connect('cpw6', 'Q1', 'b', 'Q6', 'c', '7000um', f'+{asym+0.4*offset_tm}um')

gui.rebuild()
gui.autoscale()
gui.screenshot()
# Out:
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# V2
p1_q = LaunchpadWirebondCoupled(design, 'P1_Q', options = dict(pos_x='5000um', pos_y='0um', orientation='180', lead_length='30um'))
p2_q = LaunchpadWirebondCoupled(design, 'P2_Q', options = dict(pos_x='1500um', pos_y='4000um', orientation='270', lead_length='30um'))
p3_q = LaunchpadWirebondCoupled(design, 'P3_Q', options = dict(pos_x='-1500um', pos_y='4000um', orientation='270', lead_length='30um'))
p4_q = LaunchpadWirebondCoupled(design, 'P4_Q', options = dict(pos_x='-5000um', pos_y='0um', orientation='0', lead_length='30um'))
p5_q = LaunchpadWirebondCoupled(design, 'P5_Q', options = dict(pos_x='-1500um', pos_y='-4000um', orientation='90', lead_length='30um'))
p6_q = LaunchpadWirebondCoupled(design, 'P6_Q', options = dict(pos_x='1500um', pos_y='-4000um', orientation='90', lead_length='30um'))

p1_c = LaunchpadWirebondCoupled(design, 'P1_C', options = dict(pos_x='5000um', pos_y='500um', orientation='180', lead_length='30um'))
p2_c = LaunchpadWirebondCoupled(design, 'P2_C', options = dict(pos_x='1000um', pos_y='4000um', orientation='270', lead_length='30um'))
p3_c = LaunchpadWirebondCoupled(design, 'P3_C', options = dict(pos_x='-2000um', pos_y='4000um', orientation='270', lead_length='30um'))
p4_c = LaunchpadWirebondCoupled(design, 'P4_C', options = dict(pos_x='-5000um', pos_y='-500um', orientation='0', lead_length='30um'))
p5_c = LaunchpadWirebondCoupled(design, 'P5_C', options = dict(pos_x='-1000um', pos_y='-4000um', orientation='90', lead_length='30um'))
p6_c = LaunchpadWirebondCoupled(design, 'P6_C', options = dict(pos_x='2000um', pos_y='-4000um', orientation='90', lead_length='30um'))

gui.rebuild()
gui.autoscale()
gui.screenshot()
# Out:
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
asym = 150
cpw_options = Dict(
    lead=Dict(
        start_straight='430um',
        end_straight='0um'),
    fillet=fillet
    )
ol1 = connect('ol1', 'Q1', 'a', 'P1_Q', 'tie', '8.6 mm', f'+{asym}um')
ol3 = connect('ol3', 'Q3', 'a', 'P3_Q', 'tie', '8.6 mm', f'+{asym}um')

asym = 200
cpw_options = Dict(
    lead=Dict(
        start_straight='535um',
        end_straight='0um'),
    fillet=fillet
    )
ol2 = connect('ol2', 'Q2', 'a', 'P2_Q', 'tie', '8.6 mm', f'+{asym}um')
ol4 = connect('ol4', 'Q4', 'a', 'P4_Q', 'tie', '8.6 mm', f'+{asym}um')

asym = 250
cpw_options = Dict(
    lead=Dict(
        start_straight='640um',
        end_straight='0um'),
    fillet=fillet
    )
ol5 = connect('ol5', 'Q5', 'a', 'P5_Q', 'tie', '8.6 mm', f'+{asym}um')
ol6 = connect('ol6', 'Q6', 'a', 'P6_Q', 'tie', '8.6 mm', f'+{asym}um')


gui.rebuild()
gui.autoscale()
gui.screenshot()
# Out:
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
from collections import OrderedDict
jogsA_in = OrderedDict()
jogsA_in[0] = ["L", '200um']

options_line_cl1 = {'pin_inputs':
            {'start_pin': {'component': 'Q1', 'pin': 'Charge_Line'},
             'end_pin': {'component': 'P1_C', 'pin': 'tie'}},
            'lead': {'start_straight': '120um', 'end_straight': '225um','start_jogged_extension': jogsA_in},
            'fillet': fillet
            }
cl1 = RouteAnchors(design, 'line_cl1', options_line_cl1)

options_line_cl2 = {'pin_inputs':
            {'start_pin': {'component': 'Q2', 'pin': 'Charge_Line'},
             'end_pin': {'component': 'P2_C', 'pin': 'tie'}},
            'lead': {'start_straight': '120um', 'end_straight': '225um','start_jogged_extension': jogsA_in},
            'fillet': fillet
            }
cl2 = RouteAnchors(design, 'line_cl2', options_line_cl2)

options_line_cl3 = {'pin_inputs':
            {'start_pin': {'component': 'Q3', 'pin': 'Charge_Line'},
             'end_pin': {'component': 'P3_C', 'pin': 'tie'}},
            'lead': {'start_straight': '120um', 'end_straight': '225um', 'start_jogged_extension': jogsA_in},
            'fillet': fillet
            }
cl3 = RouteAnchors(design, 'line_cl3', options_line_cl3)

options_line_cl4 = {'pin_inputs':
            {'start_pin': {'component': 'Q4', 'pin': 'Charge_Line'},
             'end_pin': {'component': 'P4_C', 'pin': 'tie'}},
            'lead': {'start_straight': '120um', 'end_straight': '225um','start_jogged_extension': jogsA_in},
            'fillet': fillet
            }
cl4 = RouteAnchors(design, 'line_cl4', options_line_cl4)

options_line_cl5 = {'pin_inputs':
            {'start_pin': {'component': 'Q5', 'pin': 'Charge_Line'},
             'end_pin': {'component': 'P5_C', 'pin': 'tie'}},
            'lead': {'start_straight': '120um', 'end_straight': '225um','start_jogged_extension': jogsA_in},
            'fillet': fillet
            }
cl5 = RouteAnchors(design, 'line_cl5', options_line_cl5)

options_line_cl6 = {'pin_inputs':
            {'start_pin': {'component': 'Q6', 'pin': 'Charge_Line'},
             'end_pin': {'component': 'P6_C', 'pin': 'tie'}},
            'lead': {'start_straight': '120um', 'end_straight': '225um','start_jogged_extension': jogsA_in},
            'fillet': fillet
            }
cl6 = RouteAnchors(design, 'line_cl6', options_line_cl6)

gui.rebuild()
gui.autoscale()
gui.screenshot()
# Out:
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\surface\Anaconda3\envs\Qiskit-Metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...
